# %%
import pandas as pd

# %%
df = pd.read_csv('df_unido.csv')

# %%
df.sample()
# Out:
#          ID         Autor  autor_codificado  compartir_tiempo fecha_compartir  \
# 6017  10006  Madison Wong                20               101      2022-10-05
#
#      hora_compartir                                             titulo  \
# 6017       03:00:00  US-led coalition killed 300 Syrian civilians i...
#
#                                                   texto  tematica  \
# 6017  RT October 26, 2016 \nAround 300 civilians wer...  Política
#
#            Fuente  ...  duracion  favorito  tiempo                    tipo  \
# 6017  Times Today  ...     166.0    6424.0     711  Noticia de última hora
#
#           pais   idioma Valores Valores_codificados fecha_tiempo hora_tiempo
# 6017  Pakistan  English    FAKE                   0   2022-09-30    22:00:00
#
# [1 rows x 23 columns]

# %%
# Filtramos los datos con base en la columna 'Valores'. Creamos dos tablas: una con todas las noticias reales y otra con todas las noticias falsas

df_real = df[df['Valores'] == 'REAL']
df_fake = df[df['Valores'] == 'FAKE']

# %%
df_real.shape
# Out:
# (3171, 23)

# %%
df_fake.shape
# Out:
# (3164, 23)

# %%
df_real.to_csv('df_real.csv', index=False)
df_fake.to_csv('df_fake.csv', index=False)
